# %% [markdown]
# # Exercise: assigning reviewers to grants submission

# %% [markdown]
# > in progress: updating this so to use dimli && being able to publish online!
#
# In this notebook we look at the problem of assigning reviewers to grants, using Dimensions as a knowledge base. Let us assume the following:
#
# * 100 grant applications (with title and abstract) are coming in
# * 20 researchers (identified with Dimensions Researcher ID) are panel members
# * The applications should be distributed among the panel members
#     * The final distribution is done manually
#     * We should inform the manual distribution with a **ranked order of researchers per grant application**, ideally with some scoring.
#     * Scoring does not have to be normalized

# %% [markdown]
# ## Approach

# %% [markdown]
# The goal is to produce a list of weighted researchers for each grant eg
# ```
# {'grant-1' : [
#     (researcher-1, 0.9), (researcher-2, 0.8), (researcher-3, 0.5)
# ]}
# ```
#
# Hence the algorithm shoud be repeated for each grant and set of researchers coming in, and it breaks down as follows:
#
# * [1] for each grant
#     * [2] for each reviewer
#         * [3] score **relevance (Rel)** of grant against reviewer expertise
#         * [4] score **conflict of interest (CoI)** of grant against reviewer network
#         * save (reviewer, Rel score, CoI score) into candidates list
#     * sort candidates list by CoI score && Rel score
#
# Steps [1] and [2] are essentially a repetition of [3] and [4], so below we show the process only for 1 grant and 1 researcher.

# %% [markdown]
# ### Sample Data

# %% [markdown]
# For the purpose of this demo we are considering a sample grant from Dimensions:
# * [grant.2554006](https://app.dimensions.ai/details/grant/grant.2554006?search_text=A%20MULTI%27OMICS%20APPROACH%20TOWARDS%20DECIPHERING%20THE%20INFLUENCE%20OF%20THE%20MICROBIOME%20ON%20PRE&search_type=kws&search_field=full_search)
#
# And one scientist/reviewer which is working in a closely associated area to the previous grant (genetics/pediatrics):
# * [ur.01316535077.54](https://app.dimensions.ai/discover/publication?and_facet_researcher=ur.01316535077.54)
#
# Next, we store this data in variables and set up the Python libraries we will use to query the Dimensions API.

# %%
import dimcli
dsl = dimcli.Dsl()

# %%
# pick a sample grant in genetics/pediatrics
sample_grant = dsl.query(
    """search grants where id="grant.2554006" return grants[title+abstract]""")
TITLE, ABSTRACT = sample_grant['grants'][0]['title'], sample_grant['grants'][0]['abstract']

# pick a sample reviewer
REVIEWER = "ur.01316535077.54"

# final list we want to obtain
CANDIDATES_LIST = []

# %% [markdown]
# ## 1. Calculating the Relevance of a Grant to a Reviewer

# %% [markdown]
# We do this by
# * extracting key terms [K1] from the grant's title and description
# * extracting key terms [K2] from the reviewer's publications in last N years (divided by title and abstract)
# * getting the overlap between the two groups [K1~K2], and generating a single score from it
#
# NOTE: the 'terms' dsl api accepts only lowercase keywords, so we use a little helper function to deal with that

# %% [markdown]
# > TODO update this after we release 1.18! extract_concepts

# %%
# helper for terms extractor PS Adam: lowercase can be omitted here
def cleanup(s):
    return s.lower().replace("'", " ").replace("\"", " ")

# concepts extractor function (encoding required to prevent unicode errors with non standard chars)
def dsl_concepts(p):
    q = """extract_terms("%s")""" % cleanup(p)
    return dsl.query(q.encode("utf-8"))['extracted_terms']

# %% [markdown]
# ### 1.1 Extract keywords from the grant title/description

# %%
GRANT_TITLE_KEYWORDS = dsl_concepts(TITLE)
GRANT_DESC_KEYWORDS = dsl_concepts(ABSTRACT)
print("GRANT_TITLE_KEYWORDS", GRANT_TITLE_KEYWORDS)
print("GRANT_DESC_KEYWORDS", GRANT_DESC_KEYWORDS)
# Out:
# GRANT_TITLE_KEYWORDS ['omics approaches', 'microbiome']
# GRANT_DESC_KEYWORDS ['microbiome', 'microbiota', 'host genomics', 'resident microbiome', 'host', 'collective genomes', 'oral microbiome', 'placenta', 'remarkable host', 'microbiome communities', 'human cells', 'sequencing', 'cells', 'sterile intrauterine environment', 'microbial gene catalogue', 'metabolomics', 'genome', 'metagenomics', 'humans', 'microbes', 'intrauterine environment', 'biomarkers', 'infection', 'hypothesis', 'birth', 'omics sciences', 'genomics', 'susceptibility', 'membrane', 'microorganisms', 'tract', 'future large-scale studies', 'community', 'human-associated microorganisms', 'human genome', 'whole-genome shotgun sequencing', 'throughput technologies', 'association', 'Aim 1', 'high-throughput technologies', 'distinct microbial communities', 'study', 'umbilical cord', 'mechanism', 'shotgun sequencing', 'large-scale studies', 'identification', 'species identification', 'mechanistic studies', 'discovery', 'genital tract', 'majority', 'levels', 'fetal membranes', 'significance', 'metatranscriptomics', 'gene catalog', 'cord', 'fetus', 'gene content', 'scale studies', 'preliminary data', 'computational pipeline', 'microbial communities', 'gestation', 'addition', 'community resources', 'broader significance', 'prior studies', 'number', 'cohort', 'transmission', 'metabolic reconstruction', 'period', 'aim', 'neonatal period', 'lower genital tract', 'data', 'risk', 'clinical studies']

# %% [markdown]
# ### 1.2 Extract keywords from the reviewer's recent publications
# We extract keywords from the reviewer's publication list in the last 5 years. This is gonna take a little while so we print out a message to show the progress of the iteration as we go through all publications.

# %%
pubs = dsl.query(f"""search publications where researchers.id="{REVIEWER}" and year>=2013 return publications[title+abstract] limit 512""")

## NOTE THIS FAILS UNLESS WE USE A BACKEND THAT SHOWS ABSTRASCTS!!!! 

REVIEWER_TITLE_KEYWORDS = []
REVIEWER_DESC_KEYWORDS = []
c, tot = 0, len(pubs['publications'])

for x in pubs['publications']:
    c += 1
    print("[%d / %d]" % (c, tot), x['title'])
    REVIEWER_TITLE_KEYWORDS += dsl_concepts(x['title'])
    REVIEWER_DESC_KEYWORDS += dsl_concepts(x['abstract'])

print("=========")
print("TOT REVIEWER_TITLE_KEYWORDS: ", len(REVIEWER_TITLE_KEYWORDS))
print("TOT REVIEWER_DESC_KEYWORDS: ", len(REVIEWER_DESC_KEYWORDS))
# Out:
# [1 / 32] BMDExpress 2: enhanced transcriptomic dose-response analysis workflow.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-cc0b6a9eba3c> in <module>
#       9     print("[%d / %d]" % (c, tot), x['title'])
#      10     REVIEWER_TITLE_KEYWORDS += dsl_concepts(x['title'])
# ---> 11     REVIEWER_DESC_KEYWORDS += dsl_concepts(x['abstract'])
#      12
#      13 print("=========")
#
# KeyError: 'abstract'

# %% [markdown]
# **Note** If we don't want to split up title/desc keywords, we can simply query like this: `search publications where researchers.id="%s" and year>=2013 return publications[terms] limit 1000`

# %%
pubs = dsl.query(f"""search publications where researchers.id="{REVIEWER}" and year>=2013 return publications""")

# %%
pubs['publications']
# Out:
# [{'pages': '1780-1782',
#   'id': 'pub.1107651006',
#   'journal': {'id': 'jour.1345383', 'title': 'Bioinformatics'},
#   'author_affiliations': [[{'first_name': 'Jason R',
#      'last_name': 'Phillips',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.013533065307.47',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Daniel L',
#      'last_name': 'Svoboda',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.015305557555.63',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Arpit',
#      'last_name': 'Tandon',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01134171264.57',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Shyam',
#      'last_name': 'Patel',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Alex',
#      'last_name': 'Sedykh',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Deepak',
#      'last_name': 'Mav',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01026374661.34',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Byron',
#      'last_name': 'Kuo',
#      'orcid': '',
#      'current_organization_id': 'grid.57544.37',
#      'researcher_id': 'ur.01277046710.03',
#      'affiliations': [{'id': 'grid.57544.37',
#        'name': 'Health Canada',
#        'city': 'Ottawa',
#        'city_id': 6094817,
#        'country': 'Canada',
#        'country_code': 'CA',
#        'state': 'Ontario',
#        'state_code': 'CA-ON'}]},
#     {'first_name': 'Carole L',
#      'last_name': 'Yauk',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.57544.37',
#        'name': 'Health Canada',
#        'city': 'Ottawa',
#        'city_id': 6094817,
#        'country': 'Canada',
#        'country_code': 'CA',
#        'state': 'Ontario',
#        'state_code': 'CA-ON'}]},
#     {'first_name': 'Longlong',
#      'last_name': 'Yang',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.07626506047.99',
#      'affiliations': [{'name': 'D.S. Technologies, Inc, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Russell S',
#      'last_name': 'Thomas',
#      'orcid': "['0000-0002-2340-0301']",
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.014165623242.92',
#      'affiliations': [{'id': 'grid.418698.a',
#        'name': 'Environmental Protection Agency',
#        'city': 'Washington D.C.',
#        'city_id': 4140963,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'District of Columbia',
#        'state_code': 'US-DC'}]},
#     {'first_name': 'Jeff S',
#      'last_name': 'Gift',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.418698.a',
#        'name': 'Environmental Protection Agency',
#        'city': 'Washington D.C.',
#        'city_id': 4140963,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'District of Columbia',
#        'state_code': 'US-DC'}]},
#     {'first_name': 'J Allen',
#      'last_name': 'Davis',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.419244.e',
#        'name': 'National Center for Environmental Assessment (EPA)',
#        'city': 'Cincinnati',
#        'city_id': 4508722,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Ohio',
#        'state_code': 'US-OH'}]},
#     {'first_name': 'Louis',
#      'last_name': 'Olszyk',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.421489.2',
#        'name': 'SRA International (United States)',
#        'city': 'Fairfax',
#        'city_id': 4758023,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Virginia',
#        'state_code': 'US-VA'}]},
#     {'first_name': 'B Alex',
#      'last_name': 'Merrick',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01020662662.84',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Fred',
#      'last_name': 'Parham',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.011351204027.38',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Trey',
#      'last_name': 'Saddler',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.013457523623.90',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Ruchir R',
#      'last_name': 'Shah',
#      'orcid': '',
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.01230533446.55',
#      'affiliations': [{'name': 'Sciome LLC, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Scott S',
#      'last_name': 'Auerbach',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01012115715.81',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]}]],
#   'issue': '10',
#   'year': 2019,
#   'type': 'article',
#   'title': 'BMDExpress 2: enhanced transcriptomic dose-response analysis workflow.',
#   'volume': '35'},
#  {'pages': '225-240',
#   'id': 'pub.1110384491',
#   'journal': {'id': 'jour.1092859', 'title': 'Toxicological Sciences'},
#   'author_affiliations': [[{'first_name': 'Celia',
#      'last_name': 'Quevedo',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.0625324030.82',
#      'affiliations': [{'name': '*Biobide, Donostia-San Sebastián, 20009 Gipuzkoa, Spain'}]},
#     {'first_name': 'Mamta',
#      'last_name': 'Behl',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01007333643.69',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Kristen',
#      'last_name': 'Ryan',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01022576271.70',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Aintzane',
#      'last_name': 'Alday',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01176057153.09',
#      'affiliations': [{'name': '*Biobide, Donostia-San Sebastián, 20009 Gipuzkoa, Spain'}]},
#     {'first_name': 'Arantza',
#      'last_name': 'Muriana',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01354571230.31',
#      'affiliations': [{'name': '*Biobide, Donostia-San Sebastián, 20009 Gipuzkoa, Spain'}]},
#     {'first_name': 'Ainhoa',
#      'last_name': 'Alzualde',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01311557653.26',
#      'affiliations': [{'name': '*Biobide, Donostia-San Sebastián, 20009 Gipuzkoa, Spain'}]}]],
#   'issue': '1',
#   'year': 2019,
#   'type': 'article',
#   'title': 'Detection and Prioritization of Developmentally Neurotoxic and/or Neurotoxic Compounds Using Zebrafish.',
#   'volume': '168'},
#  {'pages': '6-14',
#   'id': 'pub.1110178414',
#   'journal': {'id': 'jour.1092859', 'title': 'Toxicological Sciences'},
#   'author_affiliations': [[{'first_name': 'Mamta',
#      'last_name': 'Behl',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01007333643.69',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Kristen',
#      'last_name': 'Ryan',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01022576271.70',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Jui-Hua',
#      'last_name': 'Hsieh',
#      'orcid': "['0000-0003-1620-1571']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01071531406.21',
#      'affiliations': [{'name': 'Kelly Government Solutions, Durham, North Carolina 27709'}]},
#     {'first_name': 'Frederick',
#      'last_name': 'Parham',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.012744145027.86',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Andrew J',
#      'last_name': 'Shapiro',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01063465700.12',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Bradley J',
#      'last_name': 'Collins',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0723510372.53',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Nisha S',
#      'last_name': 'Sipes',
#      'orcid': "['0000-0003-4203-6426']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01264022540.41',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Linda S',
#      'last_name': 'Birnbaum',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01204537220.28',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'John R',
#      'last_name': 'Bucher',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0636142512.33',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Paul M D',
#      'last_name': 'Foster',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.016513341032.18',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Nigel J',
#      'last_name': 'Walker',
#      'orcid': "['0000-0002-9111-6855']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01120750132.84',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Raymond R',
#      'last_name': 'Tice',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01120026037.03',
#      'affiliations': [{'name': 'RTice Consulting, Hillsborough, North Carolina 27278'}]}]],
#   'issue': '1',
#   'year': 2019,
#   'type': 'article',
#   'title': 'Screening for Developmental Neurotoxicity at the National Toxicology Program: The Future Is Here.',
#   'volume': '167'},
#  {'pages': '40-50',
#   'id': 'pub.1107478192',
#   'journal': {'id': 'jour.1097316', 'title': 'Neurotoxicology and Teratology'},
#   'author_affiliations': [[{'first_name': 'Ainhoa',
#      'last_name': 'Alzualde',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01311557653.26',
#      'affiliations': [{'name': 'BIOBIDE, Donostia - San Sebastián, Gipuzkoa, Spain'}]},
#     {'first_name': 'Mamta',
#      'last_name': 'Behl',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01007333643.69',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Nisha S.',
#      'last_name': 'Sipes',
#      'orcid': "['0000-0003-4203-6426']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01264022540.41',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Jui-Hua',
#      'last_name': 'Hsieh',
#      'orcid': "['0000-0003-1620-1571']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01071531406.21',
#      'affiliations': [{'name': 'Kelly Government Solutions, Research Triangle Park, NC, United States of America'}]},
#     {'first_name': 'Aintzane',
#      'last_name': 'Alday',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01176057153.09',
#      'affiliations': [{'name': 'BIOBIDE, Donostia - San Sebastián, Gipuzkoa, Spain'}]},
#     {'first_name': 'Raymond R.',
#      'last_name': 'Tice',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01120026037.03',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Arantza',
#      'last_name': 'Muriana',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01354571230.31',
#      'affiliations': [{'name': 'BIOBIDE, Donostia - San Sebastián, Gipuzkoa, Spain'}]},
#     {'first_name': 'Celia',
#      'last_name': 'Quevedo',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.0625324030.82',
#      'affiliations': [{'name': 'BIOBIDE, Donostia - San Sebastián, Gipuzkoa, Spain'}]}]],
#   'year': 2018,
#   'type': 'article',
#   'title': 'Toxicity profiling of flame retardants in zebrafish embryos using a battery of assays for developmental toxicity, neurotoxicity, cardiotoxicity and hepatotoxicity toward human relevance',
#   'volume': '70'},
#  {'pages': '485',
#   'id': 'pub.1107895965',
#   'journal': {'id': 'jour.1045144', 'title': 'Frontiers in Genetics'},
#   'author_affiliations': [[{'first_name': 'Pierre R.',
#      'last_name': 'Bushel',
#      'orcid': "['0000-0001-5188-8693']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01270027137.66',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Scott S.',
#      'last_name': 'Auerbach',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01012115715.81',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]}]],
#   'year': 2018,
#   'type': 'article',
#   'title': 'A Comparison of the TempO-Seq S1500+ Platform to RNA-Seq and Microarray Using Rat Liver Mode of Action Samples',
#   'volume': '9'},
#  {'pages': '077010',
#   'id': 'pub.1105904462',
#   'journal': {'id': 'jour.1031925',
#    'title': 'Environmental Health Perspectives'},
#   'author_affiliations': [[{'first_name': 'Menghang',
#      'last_name': 'Xia',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.01226753254.16',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Ruili',
#      'last_name': 'Huang',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.0715015731.01',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Qiang',
#      'last_name': 'Shi',
#      'orcid': '',
#      'current_organization_id': 'grid.483504.e',
#      'researcher_id': 'ur.01066057675.42',
#      'affiliations': [{'id': 'grid.483504.e',
#        'name': 'National Center for Toxicological Research',
#        'city': 'Jefferson',
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Arkansas',
#        'state_code': 'US-AR'}]},
#     {'first_name': 'Windy A',
#      'last_name': 'Boyd',
#      'orcid': "['0000-0003-3803-3716']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01211573263.06',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Jinghua',
#      'last_name': 'Zhao',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.01326605711.02',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Nuo',
#      'last_name': 'Sun',
#      'orcid': '',
#      'current_organization_id': 'grid.279885.9',
#      'researcher_id': 'ur.0766166036.02',
#      'affiliations': [{'id': 'grid.279885.9',
#        'name': 'National Heart Lung and Blood Institute',
#        'city': 'Bethesda',
#        'city_id': 4348599,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Julie R',
#      'last_name': 'Rice',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01225733430.99',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Paul E',
#      'last_name': 'Dunlap',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Amber J',
#      'last_name': 'Hackstadt',
#      'orcid': '',
#      'current_organization_id': 'grid.412807.8',
#      'researcher_id': 'ur.01263427406.58',
#      'affiliations': [{'id': 'grid.280861.5',
#        'name': 'Social and Scientific Systems (United States)',
#        'city': 'Silver Spring',
#        'city_id': 4369596,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Matt F',
#      'last_name': 'Bridge',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.280861.5',
#        'name': 'Social and Scientific Systems (United States)',
#        'city': 'Silver Spring',
#        'city_id': 4369596,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Marjolein V',
#      'last_name': 'Smith',
#      'orcid': '',
#      'current_organization_id': 'grid.280861.5',
#      'researcher_id': 'ur.010621151577.06',
#      'affiliations': [{'id': 'grid.280861.5',
#        'name': 'Social and Scientific Systems (United States)',
#        'city': 'Silver Spring',
#        'city_id': 4369596,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Sheng',
#      'last_name': 'Dai',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.011637001261.08',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Wei',
#      'last_name': 'Zheng',
#      'orcid': "['0000-0003-1034-0757']",
#      'current_organization_id': 'grid.412807.8',
#      'researcher_id': 'ur.016425765167.70',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Pei-Hsuan',
#      'last_name': 'Chu',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.011225552237.19',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'David',
#      'last_name': 'Gerhold',
#      'orcid': "['0000-0001-5739-730X']",
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.01304544765.81',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Kristine L',
#      'last_name': 'Witt',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01305002445.33',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Michael',
#      'last_name': 'DeVito',
#      'orcid': "['0000-0003-1258-4894']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0772673506.85',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Jonathan H',
#      'last_name': 'Freedman',
#      'orcid': '',
#      'current_organization_id': 'grid.266623.5',
#      'researcher_id': 'ur.01001117530.45',
#      'affiliations': [{'id': 'grid.266623.5',
#        'name': 'University of Louisville',
#        'city': 'Louisville',
#        'city_id': 4299276,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Kentucky',
#        'state_code': 'US-KY'}]},
#     {'first_name': 'Christopher P',
#      'last_name': 'Austin',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.016155740077.21',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Keith A',
#      'last_name': 'Houck',
#      'orcid': "['0000-0002-0055-2249']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.0717355762.70',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Russell S',
#      'last_name': 'Thomas',
#      'orcid': "['0000-0002-2340-0301']",
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.014165623242.92',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Raymond R',
#      'last_name': 'Tice',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01120026037.03',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, North Carolina, USA.'}]},
#     {'first_name': 'Anton',
#      'last_name': 'Simeonov',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.0664742531.51',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]}]],
#   'issue': '7',
#   'year': 2018,
#   'type': 'article',
#   'title': 'Comprehensive Analyses and Prioritization of Tox21 10K Chemicals Affecting Mitochondrial Function by in-Depth Mechanistic Studies',
#   'volume': '126'},
#  {'pages': 'e0191105',
#   'id': 'pub.1101134587',
#   'journal': {'id': 'jour.1037553', 'title': 'PLoS ONE'},
#   'author_affiliations': [[{'first_name': 'Deepak',
#      'last_name': 'Mav',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01026374661.34',
#      'affiliations': [{'name': 'SciOme LLC, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Ruchir R.',
#      'last_name': 'Shah',
#      'orcid': '',
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.01230533446.55',
#      'affiliations': [{'name': 'SciOme LLC, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Brian E.',
#      'last_name': 'Howard',
#      'orcid': '',
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.01204747643.78',
#      'affiliations': [{'name': 'SciOme LLC, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Scott S.',
#      'last_name': 'Auerbach',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01012115715.81',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Pierre R.',
#      'last_name': 'Bushel',
#      'orcid': "['0000-0001-5188-8693']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01270027137.66',
#      'affiliations': [{'name': 'Division of Intramural Research, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Jennifer B.',
#      'last_name': 'Collins',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.016151433767.87',
#      'affiliations': [{'name': 'Division of Extramural Research and Training, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'David L.',
#      'last_name': 'Gerhold',
#      'orcid': "['0000-0001-5739-730X']",
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.01304544765.81',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Judson',
#      'orcid': "['0000-0002-2348-9633']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.01027430163.18',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Agnes L.',
#      'last_name': 'Karmaus',
#      'orcid': "['0000-0003-4421-6164']",
#      'current_organization_id': 'grid.280855.2',
#      'researcher_id': 'ur.01127325367.38',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, United States of America'},
#       {'name': 'Current address: Integrated Laboratory Systems, Inc., Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Elizabeth A.',
#      'last_name': 'Maull',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0621256102.27',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Donna L.',
#      'last_name': 'Mendrick',
#      'orcid': '',
#      'current_organization_id': 'grid.483504.e',
#      'researcher_id': 'ur.01022755750.31',
#      'affiliations': [{'id': 'grid.483504.e',
#        'name': 'National Center for Toxicological Research',
#        'city': 'Jefferson',
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Arkansas',
#        'state_code': 'US-AR'}]},
#     {'first_name': 'B. Alex',
#      'last_name': 'Merrick',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01020662662.84',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Nisha S.',
#      'last_name': 'Sipes',
#      'orcid': "['0000-0003-4203-6426']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01264022540.41',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Daniel',
#      'last_name': 'Svoboda',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.015305557555.63',
#      'affiliations': [{'name': 'SciOme LLC, Research Triangle Park, North Carolina, United States of America'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Research Triangle Park, North Carolina, United States of America'}]}]],
#   'issue': '2',
#   'year': 2018,
#   'type': 'article',
#   'title': 'A hybrid gene selection approach to create the S1500+ targeted gene sets for use in high-throughput transcriptomics',
#   'volume': '13'},
#  {'pages': '163-168',
#   'id': 'pub.1101484337',
#   'journal': {'id': 'jour.1022934', 'title': 'ALTEX'},
#   'author_affiliations': [[{'first_name': 'Russell S',
#      'last_name': 'Thomas',
#      'orcid': "['0000-0002-2340-0301']",
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.014165623242.92',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, NC,USA.'}]},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Anton',
#      'last_name': 'Simeonov',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.0664742531.51',
#      'affiliations': [{'id': 'grid.429651.d',
#        'name': 'National Center for Advancing Translational Sciences',
#        'city': 'Rockville',
#        'city_id': 4367175,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Suzanne C',
#      'last_name': 'Fitzpatrick',
#      'orcid': '',
#      'current_organization_id': 'grid.483501.b',
#      'researcher_id': 'ur.01227125540.27',
#      'affiliations': [{'id': 'grid.417587.8',
#        'name': 'United States Food and Drug Administration',
#        'city': 'Silver Spring',
#        'city_id': 4369596,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Kevin M',
#      'last_name': 'Crofton',
#      'orcid': "['0000-0003-1749-9971']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.01330766343.44',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, NC,USA.'}]},
#     {'first_name': 'Warren M',
#      'last_name': 'Casey',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01312317761.58',
#      'affiliations': [{'name': 'National Toxicology Program, Interagency Center for the Evaluation of Alternative Toxicological Methods, Research Triangle Park, NC, USA.'}]},
#     {'first_name': 'Donna L',
#      'last_name': 'Mendrick',
#      'orcid': '',
#      'current_organization_id': 'grid.483504.e',
#      'researcher_id': 'ur.01022755750.31',
#      'affiliations': [{'id': 'grid.483504.e',
#        'name': 'National Center for Toxicological Research',
#        'city': 'Jefferson',
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Arkansas',
#        'state_code': 'US-AR'}]}]],
#   'issue': '2',
#   'year': 2018,
#   'type': 'article',
#   'title': 'The US Federal Tox21 Program: A strategic and operational plan for continued leadership.',
#   'volume': '35'},
#  {'pages': '189-190',
#   'id': 'pub.1092126019',
#   'journal': {'id': 'jour.1092859', 'title': 'Toxicological Sciences'},
#   'author_affiliations': [[{'first_name': 'Sreenivasa C',
#      'last_name': 'Ramaiahgari',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0706716445.50',
#      'affiliations': []},
#     {'first_name': 'Suramya',
#      'last_name': 'Waidyanatha',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0751502173.52',
#      'affiliations': []},
#     {'first_name': 'Darlene',
#      'last_name': 'Dixon',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0700524217.99',
#      'affiliations': []},
#     {'first_name': 'Michael J',
#      'last_name': 'DeVito',
#      'orcid': "['0000-0003-1258-4894']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0772673506.85',
#      'affiliations': []},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': []},
#     {'first_name': 'Stephen S',
#      'last_name': 'Ferguson',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01200642523.64',
#      'affiliations': []}]],
#   'issue': '1',
#   'year': 2017,
#   'type': 'article',
#   'title': 'Three-Dimensional (3D) HepaRG Spheroid Model With Physiologically Relevant Xenobiotic Metabolism Competence and Hepatocyte Functionality for Liver Toxicity Screening.',
#   'volume': '160'},
#  {'pages': '124-136',
#   'id': 'pub.1086006129',
#   'journal': {'id': 'jour.1092859', 'title': 'Toxicological Sciences'},
#   'author_affiliations': [[{'first_name': 'Sreenivasa C',
#      'last_name': 'Ramaiahgari',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0706716445.50',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Suramya',
#      'last_name': 'Waidyanatha',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0751502173.52',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Darlene',
#      'last_name': 'Dixon',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0700524217.99',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Michael J',
#      'last_name': 'DeVito',
#      'orcid': "['0000-0003-1258-4894']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0772673506.85',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Stephen S',
#      'last_name': 'Ferguson',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01200642523.64',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]}]],
#   'issue': '1',
#   'year': 2017,
#   'type': 'article',
#   'title': 'From the Cover: Three-Dimensional (3D) HepaRG Spheroid Model With Physiologically Relevant Xenobiotic Metabolism Competence and Hepatocyte Functionality for Liver Toxicity Screening.',
#   'volume': '159'},
#  {'pages': 'e0181291',
#   'id': 'pub.1090369793',
#   'journal': {'id': 'jour.1037553', 'title': 'PLoS ONE'},
#   'author_affiliations': [[{'first_name': 'Jui-Hua',
#      'last_name': 'Hsieh',
#      'orcid': "['0000-0003-1620-1571']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01071531406.21',
#      'affiliations': []},
#     {'first_name': 'Ruili',
#      'last_name': 'Huang',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.0715015731.01',
#      'affiliations': []},
#     {'first_name': 'Ja-An',
#      'last_name': 'Lin',
#      'orcid': '',
#      'current_organization_id': 'grid.417587.8',
#      'researcher_id': 'ur.013613311777.36',
#      'affiliations': []},
#     {'first_name': 'Alexander',
#      'last_name': 'Sedykh',
#      'orcid': '',
#      'current_organization_id': 'grid.10698.36',
#      'researcher_id': 'ur.015033067307.14',
#      'affiliations': []},
#     {'first_name': 'Jinghua',
#      'last_name': 'Zhao',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.01326605711.02',
#      'affiliations': []},
#     {'first_name': 'Raymond R',
#      'last_name': 'Tice',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01120026037.03',
#      'affiliations': []},
#     {'first_name': 'Richard S',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': []},
#     {'first_name': 'Menghang',
#      'last_name': 'Xia',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.01226753254.16',
#      'affiliations': []},
#     {'first_name': 'Scott S',
#      'last_name': 'Auerbach',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01012115715.81',
#      'affiliations': []}]],
#   'issue': '7',
#   'year': 2017,
#   'type': 'article',
# ...
#     {'first_name': 'Liwen',
#      'last_name': 'Liu',
#      'orcid': '',
#      'current_organization_id': 'grid.94365.3d',
#      'researcher_id': 'ur.0636366006.68',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Kevin',
#      'last_name': 'Gerrish',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01200065604.06',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Silvya Stuchi',
#      'last_name': 'Maria-Engler',
#      'orcid': "['0000-0003-4771-6041']",
#      'current_organization_id': 'grid.11899.38',
#      'researcher_id': 'ur.01324616001.77',
#      'affiliations': [{'id': 'grid.11899.38',
#        'name': 'University of Sao Paulo',
#        'city': 'São Paulo',
#        'city_id': 3448439,
#        'country': 'Brazil',
#        'country_code': 'BR',
#        'state': None,
#        'state_code': None}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Silvia Berlanga',
#      'last_name': 'de Moraes Barros',
#      'orcid': '',
#      'current_organization_id': 'grid.11899.38',
#      'researcher_id': 'ur.0626422265.59',
#      'affiliations': [{'id': 'grid.11899.38',
#        'name': 'University of Sao Paulo',
#        'city': 'São Paulo',
#        'city_id': 3448439,
#        'country': 'Brazil',
#        'country_code': 'BR',
#        'state': None,
#        'state_code': None}]}]],
#   'issue': 'Food Chem. Toxicol. 14 2003',
#   'year': 2017,
#   'type': 'article',
#   'title': 'Molecular effects of 1-naphthyl-methylcarbamate and solar radiation exposures on human melanocytes',
#   'volume': '38'},
#  {'pages': 'a8-a11',
#   'id': 'pub.1064736939',
#   'journal': {'id': 'jour.1031925',
#    'title': 'Environmental Health Perspectives'},
#   'author_affiliations': [[{'first_name': 'Keith A.',
#      'last_name': 'Houck',
#      'orcid': "['0000-0002-0055-2249']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.0717355762.70',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Judson',
#      'orcid': "['0000-0002-2348-9633']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.01027430163.18',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Thomas B.',
#      'last_name': 'Knudsen',
#      'orcid': '',
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.01101717562.21',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Matthew T.',
#      'last_name': 'Martin',
#      'orcid': "['0000-0002-8096-9908']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.01303220345.66',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Ann M.',
#      'last_name': 'Richard',
#      'orcid': '',
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.0766007657.99',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Kevin M.',
#      'last_name': 'Crofton',
#      'orcid': "['0000-0003-1749-9971']",
#      'current_organization_id': 'grid.418698.a',
#      'researcher_id': 'ur.01330766343.44',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Anton',
#      'last_name': 'Simeonov',
#      'orcid': '',
#      'current_organization_id': 'grid.429651.d',
#      'researcher_id': 'ur.0664742531.51',
#      'affiliations': [{'id': 'grid.94365.3d',
#        'name': 'National Institutes of Health',
#        'city': 'Bethesda',
#        'city_id': 4348599,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Maryland',
#        'state_code': 'US-MD'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'name': 'National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Department of Health and Human Services, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'John R.',
#      'last_name': 'Bucher',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.0636142512.33',
#      'affiliations': [{'name': 'National Toxicology Program, National Institute of Environmental Health Sciences, National Institutes of Health, Department of Health and Human Services, Research Triangle Park, North Carolina, USA'}]},
#     {'first_name': 'Russell S.',
#      'last_name': 'Thomas',
#      'orcid': "['0000-0002-2340-0301']",
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.014165623242.92',
#      'affiliations': [{'name': 'National Center for Computational Toxicology, Office of Research and Development, U.S. Environmental Protection Agency, Research Triangle Park, North Carolina, USA'}]}]],
#   'issue': '1',
#   'year': 2017,
#   'type': 'article',
#   'title': 'Comment on “On the Utility of ToxCast™ and ToxPi as Methods for Identifying New Obesogens”',
#   'volume': '125'},
#  {'pages': 's279',
#   'id': 'pub.1013412642',
#   'journal': {'id': 'jour.1087073', 'title': 'Toxicology Letters'},
#   'author_affiliations': [[{'first_name': 'H.',
#      'last_name': 'VanSteenhouse',
#      'orcid': '',
#      'current_organization_id': 'grid.465144.6',
#      'researcher_id': 'ur.01346122743.39',
#      'affiliations': [{'name': 'BioSpyder Technologies, United States'}]},
#     {'first_name': 'M.',
#      'last_name': 'Babic',
#      'orcid': "['0000-0002-4040-0370']",
#      'current_organization_id': 'grid.465144.6',
#      'researcher_id': 'ur.013377555206.52',
#      'affiliations': [{'name': 'BioSpyder Technologies, United States'}]},
#     {'first_name': 'P.',
#      'last_name': 'Shepard',
#      'orcid': '',
#      'current_organization_id': 'grid.465144.6',
#      'researcher_id': 'ur.015027320726.65',
#      'affiliations': [{'name': 'BioSpyder Technologies, United States'}]},
#     {'first_name': 'S.',
#      'last_name': 'Auerbach',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01012115715.81',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'A.',
#      'last_name': 'Merrick',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'D.',
#      'last_name': 'Mav',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01026374661.34',
#      'affiliations': [{'name': 'Sciome, LLC, United States'}]},
#     {'first_name': 'R.',
#      'last_name': 'Shah',
#      'orcid': '',
#      'current_organization_id': 'grid.419178.2',
#      'researcher_id': 'ur.01230533446.55',
#      'affiliations': [{'name': 'Sciome, LLC, United States'}]},
#     {'first_name': 'R.S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'J.',
#      'last_name': 'Yeakley',
#      'orcid': '',
#      'current_organization_id': 'grid.465144.6',
#      'researcher_id': 'ur.01120610164.00',
#      'affiliations': [{'name': 'BioSpyder Technologies, United States'}]},
#     {'first_name': 'B.',
#      'last_name': 'Seligmann',
#      'orcid': '',
#      'current_organization_id': 'grid.465144.6',
#      'researcher_id': 'ur.01014063606.33',
#      'affiliations': [{'name': 'BioSpyder Technologies, United States'}]}]],
#   'year': 2016,
#   'type': 'article',
#   'title': 'TempO-Seq surrogate whole transcriptome targeted gene expression profiling of archived rat FFPE',
#   'volume': '258'},
#  {'pages': '432-441',
#   'id': 'pub.1012259255',
#   'journal': {'id': 'jour.1017409',
#    'title': 'Clinical Pharmacology & Therapeutics'},
#   'author_affiliations': [[{'first_name': 'RD',
#      'last_name': 'Fannin',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'K',
#      'last_name': 'Gerrish',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01200065604.06',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'SO',
#      'last_name': 'Sieber',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01025770366.45',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'PR',
#      'last_name': 'Bushel',
#      'orcid': "['0000-0001-5188-8693']",
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01270027137.66',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'PB',
#      'last_name': 'Watkins',
#      'orcid': '',
#      'current_organization_id': 'grid.10698.36',
#      'researcher_id': 'ur.0720632177.57',
#      'affiliations': [{'name': 'Hamner – University of North Carolina Institute for Drug Safety Sciences Research Triangle Park North Carolina USA'}]},
#     {'first_name': 'RS',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'id': 'grid.280664.e',
#        'name': 'National Institute of Environmental Health Sciences',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]}]],
#   'issue': '4',
#   'year': 2016,
#   'type': 'article',
#   'title': 'Blood transcript immune signatures distinguish a subset of people with elevated serum ALT from others given acetaminophen',
#   'volume': '99'},
#  {'pages': '13-14',
#   'id': 'pub.1012858032',
#   'journal': {'id': 'jour.1097894', 'title': 'Reproductive Toxicology'},
#   'author_affiliations': [[{'first_name': 'Ainhoa',
#      'last_name': 'Alzualde',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01311557653.26',
#      'affiliations': [{'name': 'BBD BioPhenix-BIOBIDE, Donostia-San Sebastian, Spain'}]},
#     {'first_name': 'Aintzane',
#      'last_name': 'Alday',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01176057153.09',
#      'affiliations': [{'name': 'BBD BioPhenix-BIOBIDE, Donostia-San Sebastian, Spain'}]},
#     {'first_name': 'Mamta',
#      'last_name': 'Behl',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01007333643.69',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, NC, USA'}]},
#     {'first_name': 'Raymond R.',
#      'last_name': 'Tice',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01120026037.03',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, NC, USA'}]},
#     {'first_name': 'Richard S.',
#      'last_name': 'Paules',
#      'orcid': '',
#      'current_organization_id': 'grid.280664.e',
#      'researcher_id': 'ur.01316535077.54',
#      'affiliations': [{'name': 'Division of the National Toxicology Program, National Institute of Environmental Health Sciences, NIH, DHHS, Research Triangle Park, NC, USA'}]},
#     {'first_name': 'Itziar',
#      'last_name': 'Irijalba',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.012537661146.33',
#      'affiliations': [{'name': 'BBD BioPhenix-BIOBIDE, Donostia-San Sebastian, Spain'}]},
#     {'first_name': 'Olaia',
#      'last_name': 'Holgado',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.0777664102.12',
#      'affiliations': [{'name': 'BBD BioPhenix-BIOBIDE, Donostia-San Sebastian, Spain'}]},
#     {'first_name': 'Arantza',
#      'last_name': 'Muriana',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01354571230.31',
#      'affiliations': [{'name': 'BBD BioPhenix-BIOBIDE, Donostia-San Sebastian, Spain'}]},
#     {'first_name': 'Celia',
#      'last_name': 'Quevedo',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.0625324030.82',
#      'affiliations': [{'name': 'BBD BioPhenix-BIOBIDE, Donostia-San Sebastian, Spain'}]}]],
#   'year': 2015,
#   'type': 'article',
#   'title': 'Toxicity profiling of flame retardants in zebrafish embryos using a battery of assays for teratogenicity, behavior, cardiotoxicity, and hepatotoxicity',
#   'volume': '56'}]

# %%
dsl.query(f"""search publications where researchers.id="{REVIEWER}" and year>=2013 return publications[concepts+id] limit 512""")
# Out:
# <dimcli.Result object #4480684816. Dict keys: '_stats', 'publications'>

# %% [markdown]
# #### Grouping by Frequency of keywords
#
# The same keyword can be found in more that one publication, so we want to take that as an indication that the reviewer is more closely associated to that topic.
# By grouping keywords this way we can end up with a dictionary where each keyword has a frequency of appearance, which can be used eventually to weight the relevancy score of a candidate.

# %%
from collections import Counter
REVIEWER_TITLE_KEYWORDS_GROUPED = Counter(REVIEWER_TITLE_KEYWORDS)
REVIEWER_DESC_KEYWORDS_GROUPED = Counter(REVIEWER_DESC_KEYWORDS)

# %% [markdown]
# Now let's print these out as a table, using the Pandas library.

# %%
import pandas as pd
# wrapper
def build_df(a_dict):
    if a_dict:
        df = pd.DataFrame.from_dict(a_dict, orient='index').reset_index()
        df = df.rename(columns={'index': 'term', 0: 'count'})
        return df
    else:
        print("No values to show")
        return pd.DataFrame() # return empty DF
print("========= REVIEWER_TITLE_KEYWORDS BY MOST FREQUENT ========")
df = build_df(REVIEWER_TITLE_KEYWORDS_GROUPED)
if not df.empty: 
    display(df.sort_values('count', ascending=False))

# %% [markdown]
# Let's do the same for the keywords extracted from the descriptions/abstracts:

# %%
print("========= REVIEWER_DESC_KEYWORDS BY MOST FREQUENT ========")
df = build_df(REVIEWER_DESC_KEYWORDS_GROUPED)
if not df.empty: display(df.sort_values('count', ascending=False))

# %% [markdown]
# ### 1.3 Calculating the keywords overlap between the grant and the reviewer publications

# %% [markdown]
# This is simply a matter of iterating through the two pair of keywords' lists, and highlighting the ones that appear in both places.
#
# **Note** we still deal with title and abstract/descriptions separately, based on the assumption that a match in the title is stronger that a match in the abstract. This will then be represented via a different weight multiplier for title matches, when calculating the final score.

# %%
print("========= OVERLAP_TITLE_KEYWORDS BY MOST FREQUENT ========")
OVERLAP_TITLE_KEYWORDS = {}
for t in GRANT_TITLE_KEYWORDS:
    if t in REVIEWER_TITLE_KEYWORDS_GROUPED.keys():
        OVERLAP_TITLE_KEYWORDS[t] = REVIEWER_TITLE_KEYWORDS_GROUPED[t]
df = build_df(OVERLAP_TITLE_KEYWORDS)
if not df.empty: display(df.sort_values('count', ascending=False))

# %% [markdown]
# **Note**
# In this case the are no title keywords in common between the grant submissiona and the reviewer!

# %%
print("========= OVERLAP_DESC_KEYWORDS BY MOST FREQUENT ========")
OVERLAP_DESC_KEYWORDS = {}
for t in GRANT_DESC_KEYWORDS:
    if t in REVIEWER_DESC_KEYWORDS_GROUPED.keys():
        OVERLAP_DESC_KEYWORDS[t] = REVIEWER_DESC_KEYWORDS_GROUPED[t]
df = build_df(OVERLAP_DESC_KEYWORDS)
if not df.empty: display(df.sort_values('count', ascending=False))

# %% [markdown]
# Finally, we want to **reduce all of these results to a single number**, so that it'll be easier to then compare it with scores for other reviewers.
#
# This can be easily achieved in two steps:
#
# * sum up all counts for description keywords
# * sum up all counts for title keywords, applying a booster coefficient eg '2'. This is because matching title keywords can be more indicative of shared expertise.
#
# The sum of the two numbers above is the final score.

# %%
TITLE_WEIGHT = 2  # multiplier that gives title hits more weight

score = (sum(OVERLAP_TITLE_KEYWORDS.values()) * TITLE_WEIGHT) + (sum(
    OVERLAP_DESC_KEYWORDS.values()))

print("The total combined relevance score is: ", score)

CANDIDATES_LIST += [
    [REVIEWER, score], 
    # other reviewers data would go here.. 
]

# %% [markdown]
# ### 1.4 Wrapping up

# %% [markdown]
# We have calculated the relevance of a *single* reviewer/researcher VS a submission by looking at the keywords-overlap of title and abstracts as distinct factors.
#
# We can easily **repeat the same process** for all the remaining N reviewers/researchers, simply by looping over a list of researcher IDs.
#
# The final scores can be added to the `CANDIDATES_LIST` variable, which can then be sorted before returning it to the end user.

# %%
CANDIDATES_LIST = sorted(CANDIDATES_LIST, key=lambda x: x[1],  reverse=True)
print(CANDIDATES_LIST)

# %% [markdown]
# ### 1.5 Addendum

# %% [markdown]
# A much faster but also much less transparent (and possibly less precise) approach would be to use a single query like this:
#
# ```
# search publications in terms for "..[1].." where researcher.id in [..[2]..] return researchers
# ```
#
# Where:
#
# * [1] is a _list of terms_ obtained from extracting terms from the grant submission title+description
# * [2] is a _list of researchers_ i.e. the list of reviewers we are trying to rank
#
# This query essentially returns a researchers-facet on a list of publications filtered by terms and reviewers. The facet includes researchers that are not in the reviewers list, which can be skipped. The results are already ordered by relevance of the keywords.
#
# Main drawback is that the relevance score is not returned, nor it is clear how it is calculated. It would be useful to test these results on real world data and compare with the previous appraoch.

# %% [markdown]
# ## 2. Calculating a Conflict of Interest score of a Reviewer VS a Grant Authors

# %% [markdown]
# Prerequisisite:
#
# * we must know the researcher ID of the authors of the grant submission
#
# Two aspects:
#
# * overlap between all coauthors of reviewer, and all authors of the grant
#     * extra: this could be extended by including grant author's co-authors, or second-degree co-authors etc..
# * overlap between all institutions of reviewer, and all institutions of the grants' authors
#     * extra: same considerations about second level objects
#     * extra: expand institutions by using full GRID hierarchy info

# %%
RESEARCHERS = ["ur.01331772327.01"]  # the authors of the grant submission, one or more
REVIEWER = "ur.01316535077.54" # the score is calculated against each single reviewer

# %% [markdown]
# ### 2.1 Co-authors overlap

# %% [markdown]
# Note: the following query retrieves co-authors based on a publications list from the last 10 years. this This will make the query faster, but of course it can be changed.

# %%
REVIEWER_PUBS_RESULTS = dsl.query(
    """search publications where researchers.id="%s" and year>=2008 return researchers limit 1000"""
    % REVIEWER)

REVIEWER_COAUTHORS = [
    x['id'] for x in REVIEWER_PUBS_RESULTS["researchers"]
    if x['id'] != REVIEWER
]

# find if there's an overlap between reviever's coauthors and the researchers
overlap = [x for x in RESEARCHERS if x in REVIEWER_COAUTHORS]
overlap_score = len(overlap)
print("CO-AUTHORS CONFLICT OF INTEREST SCORE (0=no, 1+=yes): \n=> ", overlap_score)

# %% [markdown]
# ### 2.2 Organizations overlap

# %%
REVIEWER_ORGANIZATIONS = next((item for item in REVIEWER_PUBS_RESULTS['researchers']
                      if item['id'] == REVIEWER), None)["research_orgs"]

RESEARCHERS_ORGANIZATIONS = []
for r in RESEARCHERS:
    res = dsl.query(
        """search publications where researchers.id="%s" return researchers limit 1"""
        % r)
    RESEARCHERS_ORGANIZATIONS += res["researchers"][0]["research_orgs"]

# find if there's an overlap between reviever's orgs and the researchers orgs
overlap_institutions = [
    x for x in RESEARCHERS_ORGANIZATIONS if x in REVIEWER_ORGANIZATIONS
]
overlap_institutions_score = len(overlap_institutions)
print("ORGANIZATIONS CONFLICT OF INTEREST SCORE (0=no, 1+=yes): \n=> ", overlap_institutions_score)

# %% [markdown]
# ### 2.3 Wrapping up

# %% [markdown]
# The steps above must be repeated for each grant submission - reviewer pair.
#
# Eventually the scores can be combined within the `CANDIDATES_LIST` result (for a given grant submission) as follows:

# %%
for c in CANDIDATES_LIST:
    if c[0] == REVIEWER:
        c += [overlap_score, overlap_institutions_score]
print(CANDIDATES_LIST)
